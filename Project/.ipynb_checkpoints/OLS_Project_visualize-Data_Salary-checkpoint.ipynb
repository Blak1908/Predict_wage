# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smf
import statsmodels.formula.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data.csv',
                usecols=['exper', 'wage'])

# %%
df
# Out:
#       exper  wage
# 0        16   548
# 1         9   481
# 2        16   721
# 3        10   250
# 4        16   729
# ...     ...   ...
# 3005      7   335
# 3006     15   481
# 3007      6   500
# 3008     13   713
# 3009      7   525
#
# [3010 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3010 entries, 0 to 3009
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   exper   3010 non-null   int64
#  1   wage    3010 non-null   int64
# dtypes: int64(2)
# memory usage: 47.2 KB

# %%
df.describe()
# Out:
#              exper         wage
# count  3010.000000  3010.000000
# mean      8.856146   577.282392
# std       4.141672   262.958302
# min       0.000000   100.000000
# 25%       6.000000   394.250000
# 50%       8.000000   537.500000
# 75%      11.000000   708.750000
# max      23.000000  2404.000000

# %%
df.isnull().sum()
# Out:
# exper    0
# wage     0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (797, 2)

# %%
df[df.duplicated()]
# Out:
#       exper  wage
# 80        8   500
# 123      15   625
# 141       8   635
# 183       6   500
# 202       6   577
# ...     ...   ...
# 2997      8   513
# 3000      8   500
# 3003      6   470
# 3006     15   481
# 3007      6   500
#
# [797 rows x 2 columns]

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(df['wage'])
plt.title('Salary Hike')
plt.subplot(122)
plt.boxplot(df['exper'])
plt.title('Years of Experience')
plt.show()

# %%
#Outlier Treatment

def outlier_detect(df):
    for i in df.describe().columns:
        Q1=df.describe().at['25%',i]
        Q3=df.describe().at['75%',i]
        IQR=Q3 - Q1
        LTV=Q1 - 1.5 * IQR
        UTV=Q3 + 1.5 * IQR
        x=np.array(df[i])
        p=[]
        for j in x:
            if j < LTV or j>UTV:
                p.append(df[i].median())
            else:
                p.append(j)
        df[i]=p
    return df

# %%
df_cleaned = outlier_detect(df)
df_cleaned
# Out:
#       exper   wage
# 0      16.0  548.0
# 1       9.0  481.0
# 2      16.0  721.0
# 3      10.0  250.0
# 4      16.0  729.0
# ...     ...    ...
# 3005    7.0  335.0
# 3006   15.0  481.0
# 3007    6.0  500.0
# 3008   13.0  713.0
# 3009    7.0  525.0
#
# [3010 rows x 2 columns]

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(df_cleaned['wage'])
plt.title('Salary Hike')
plt.subplot(122)
plt.boxplot(df_cleaned['exper'])
plt.title('Years of Experience')
plt.show()

# %%
df.corr()
# Out:
#           exper      wage
# exper  1.000000  0.030035
# wage   0.030035  1.000000

# %% [markdown]
# Visualization of Correlation beteen x and y

# %%
sns.regplot(x=df['exper'],y=df['wage'])
# Out:
# <AxesSubplot: xlabel='exper', ylabel='wage'>

# %%
plt.figure(figsize = (8,6), facecolor = 'lightgreen')
sns.scatterplot(x = df['exper'], y = df['wage'])
plt.title('Homoscedasticity', fontweight = 'bold', fontsize = 16)
plt.show()

# %%
df.var()
# Out:
# exper       17.153443
# wage     69147.068783
# dtype: float64

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Trying different transformation of data to estimate normal distribution and remove any skewness

# %%
sns.distplot(df['exper'], bins = 10, kde = True)
plt.title('Before Transformation')
sns.displot(np.log(df['exper']), bins = 10, kde = True)
plt.title('After Transformation')
plt.show()

# %%
df['exper'].isnull().value_counts()
# Out:
# False    3010
# Name: exper, dtype: int64

# %%
check = np.log(df['exper'])
count = 0
for i in check:
    if np.isinf(i):
        print(count)
    count += 1
# Out:
# 65
# 384
# 747
# 858
# 1074
# 1095
# 1097
# 1800
# 2461

# %%
df['exper'] = df['exper'].drop(df['exper'][df.exper == 0].index)

# %%
labels = ['Before Transformation','After Transformation']
sns.distplot(df['exper'], bins = 10, kde = True)
sns.distplot(np.log(df['exper']), bins = 10, kde = True)
plt.legend(labels)
plt.show()

# %% [markdown]
# How log transformation affects the data and it scales the values down.
# Before prediction it is necessary to reverse scaled the values, even for calculating RMSE for the models.(Errors)

# %%
smf.qqplot(np.log(df['exper']), line = 'r')
plt.title('No transformation')
smf.qqplot(np.sqrt(df['exper']), line = 'r')
plt.title('Log transformation')
smf.qqplot(np.sqrt(df['exper']), line = 'r')
plt.title('Square root transformation')
smf.qqplot(np.cbrt(df['exper']), line = 'r')
plt.title('Cube root transformation')
plt.show()

# %% [markdown]
# Fitting a Linear Regression Model
# Using Ordinary least squares (OLS) regression
# It is a statistical method of analysis that estimates the relationship between one or more independent variables and a dependent variable; the method estimates the relationship by minimizing the sum of the squares in the difference between the observed and predicted values of the dependent variable configured as a straight line

# %%
import statsmodels.formula.api as sm
model = sm.ols('wage~exper', data = df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.138
# Date:                Sat, 22 Oct 2022   Prob (F-statistic):             0.0133
# Time:                        15:11:01   Log-Likelihood:                -20384.
# No. Observations:                3010   AIC:                         4.077e+04
# Df Residuals:                    3008   BIC:                         4.078e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    530.2203      9.501     55.807      0.000     511.591     548.849
# exper          2.4776      1.000      2.478      0.013       0.517       4.438
# ==============================================================================
# Omnibus:                      114.282   Durbin-Watson:                   1.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.422
# Skew:                           0.492   Prob(JB):                     5.82e-28
# Kurtosis:                       2.819   Cond. No.                         23.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The R-squared and Adjusted R-squared scores are above 0.85.
# (It is a thumb rule to consider Adjusted R-squared to be greater than 0.8 for a good model for prediction)
# F-statitics is quite high as well and yes desire it to be higher
# But log-likelihood is quite very low far away from 0
# and AIC and BIC score are much higher for this model
# Lets Try some data transformation to check whether these scores can get any better than this.

# %% [markdown]
# Square Root transformation on data

# %%
model1 = sm.ols('np.sqrt(wage)~np.sqrt(exper)', data = df).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.sqrt(wage)   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.897
# Date:                Sat, 22 Oct 2022   Prob (F-statistic):            0.00868
# Time:                        15:11:05   Log-Likelihood:                -8816.3
# No. Observations:                3010   AIC:                         1.764e+04
# Df Residuals:                    3008   BIC:                         1.765e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         22.1318      0.358     61.756      0.000      21.429      22.835
# np.sqrt(exper)     0.3194      0.122      2.626      0.009       0.081       0.558
# ==============================================================================
# Omnibus:                       39.649   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.496
# Skew:                           0.041   Prob(JB):                     4.79e-06
# Kurtosis:                       2.566   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The R-squared and Adjusted R-squared scores are above 0.85. but its has gotten less than previous model
# (It is a thumb rule to consider Adjusted R-squared to be greater than 0.8 for a good model for prediction)
# F-statitics has gotten a little lower for this model than previous.
# But log-likelihood got better than before close to 0 higher than previous model
# and AIC and BIC score are now much better for this model
# Lets Try some data transformation to check whether these scores can get any better than this.

# %%
model2 = sm.ols('np.cbrt(wage)~np.cbrt(exper)', data = df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.cbrt(wage)   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.954
# Date:                Sat, 22 Oct 2022   Prob (F-statistic):            0.00841
# Time:                        15:11:08   Log-Likelihood:                -4468.5
# No. Observations:                3010   AIC:                             8941.
# Df Residuals:                    3008   BIC:                             8953.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          7.7472      0.121     63.817      0.000       7.509       7.985
# np.cbrt(exper)     0.1576      0.060      2.637      0.008       0.040       0.275
# ==============================================================================
# Omnibus:                       34.696   Durbin-Watson:                   1.633
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.324
# Skew:                          -0.120   Prob(JB):                     3.17e-06
# Kurtosis:                       2.620   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model3 = sm.ols('np.log(wage)~np.log(exper)', data = df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(wage)   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.703
# Date:                Sat, 22 Oct 2022   Prob (F-statistic):            0.00967
# Time:                        15:11:11   Log-Likelihood:                -1575.4
# No. Observations:                3010   AIC:                             3155.
# Df Residuals:                    3008   BIC:                             3167.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         6.1596      0.030    205.845      0.000       6.101       6.218
# np.log(exper)     0.0367      0.014      2.589      0.010       0.009       0.065
# ==============================================================================
# Omnibus:                       99.108   Durbin-Watson:                   1.633
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.571
# Skew:                          -0.465   Prob(JB):                     2.65e-24
# Kurtosis:                       3.021   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Model Testing
# As Y = Beta0 + Beta1*(X)

# %% [markdown]
# Finding Coefficient Parameters (Beta0 and Beta1 values)

# %%
model.params
# Out:
# Intercept    530.220332
# exper          2.477603
# dtype: float64

# %% [markdown]
# Here, (Intercept) Beta0 value = 560.394232 & (YearsExperience) Beta1 value =  1.906942
# Hypothesis testing of X variable by finding test_statistics and P_values for Beta1 i.e if (P_value < α=0.05 ; Reject Null)
# Null Hypothesis as Beta1=0 (No Slope) and Alternate Hypthesis as Beta1≠0 (Some or significant Slope)

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept    55.806756
# exper         2.477534
# dtype: float64
#  Intercept    0.000000
# exper        0.013284
# dtype: float64

# %% [markdown]
# (Intercept) Beta0: tvalue=49.537709 , pvalue=0.000000
# (daily) Beta1: tvalue=1.648015, pvalue= 1.648015
# As (pvalue=0)<(α=0.05); Reject Null hyp. Thus, X(YearsExperience) variable has good slope and variance w.r.t Y(Salary) variable.
# R-squared measures the strength of the relationship between your model and the dependent variable on a 0 – 100% scale.
# Measure goodness-of-fit by finding rsquared values (percentage of variance)

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.002036461457090133, 0.001704691663691582)

# %% [markdown]
# Determination Coefficient = rsquared value = 0.95 ; very good fit >= 85%

# %%
import statsmodels.api as sm
sm.qqplot(model.resid, line = 'q')
plt.title('Normal Q-Q plot of residuals of Model without any data transformation')
plt.show()

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues), get_standardized_values(model.resid))
plt.title('Residual Plot for Model without any data transformation')
plt.xlabel('Standardized Fitted Values')
plt.ylabel('Standardized Residual Values')
plt.show()

# %% [markdown]
# Model Validation

# %% [markdown]
# We will analyze Mean Squared Error (MSE) or Root Mean Squared Error (RMSE) — AKA the average distance (squared to get rid of negative numbers) between the model’s predicted target value and the actual target value.

# %% [markdown]
# Comparing different models with respect to the Root Mean Squared Errors

# %%
from sklearn.metrics import mean_squared_error

# %%
model1_pred_y =np.square(model1.predict(df['exper']))
model2_pred_y =pow(model2.predict(df['exper']),3)
model3_pred_y =np.exp(model3.predict(df['exper']))

# %%
model1_rmse =np.sqrt(mean_squared_error(df['wage'], model1_pred_y))
model2_rmse =np.sqrt(mean_squared_error(df['wage'], model2_pred_y))
model3_rmse =np.sqrt(mean_squared_error(df['wage'], model3_pred_y))
print('model=', np.sqrt(model.mse_resid),'\n' 'model1=', model1_rmse,'\n' 'model2=', model2_rmse,'\n' 'model3=', model3_rmse)
# Out:
# model= 211.36530226781133
# model1= 212.20364998148125
# model2= 212.96354145963286
# model3= 215.1955226819475

# %%
rmse = {'model': np.sqrt(model.mse_resid), 'model1': model1_rmse, 'model2': model3_rmse, 'model3' : model3_rmse}
min(rmse, key=rmse.get)
# Out:
# 'model'

# %% [markdown]
# Predicting values

# %%
# first model results without any transformation
predicted2 = pd.DataFrame()
predicted2['exper'] = df.exper
predicted2['wage'] = df.wage
predicted2['Predicted_wage'] = pd.DataFrame(model.predict(df['exper']))
predicted2
# Out:
#       exper   wage  Predicted_wage
# 0      16.0  548.0      569.861987
# 1       9.0  481.0      552.518763
# 2      16.0  721.0      569.861987
# 3      10.0  250.0      554.996366
# 4      16.0  729.0      569.861987
# ...     ...    ...             ...
# 3005    7.0  335.0      547.563556
# 3006   15.0  481.0      567.384383
# 3007    6.0  500.0      545.085952
# 3008   13.0  713.0      562.429177
# 3009    7.0  525.0      547.563556
#
# [3010 rows x 3 columns]
