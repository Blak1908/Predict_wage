# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smf
import statsmodels.formula.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('wage.csv')

# %%
df.describe()
# Out:
#                 id       nearc2       nearc4         educ          age  \
# count  3010.000000  3010.000000  3010.000000  3010.000000  3010.000000
# mean   2581.748837     0.440864     0.682060    13.263455    28.119601
# std    1500.538849     0.496573     0.465753     2.676913     3.137004
# min       2.000000     0.000000     0.000000     1.000000    24.000000
# 25%    1275.500000     0.000000     0.000000    12.000000    25.000000
# 50%    2541.000000     0.000000     1.000000    13.000000    28.000000
# 75%    3858.750000     1.000000     1.000000    16.000000    31.000000
# max    5225.000000     1.000000     1.000000    18.000000    34.000000
#
#           fatheduc     motheduc        weight     momdad14     sinmom14  ...  \
# count  2320.000000  2657.000000  3.010000e+03  3010.000000  3010.000000  ...
# mean     10.003448    10.348137  3.211853e+05     0.789369     0.100664  ...
# std       3.720737     3.179671  1.706458e+05     0.407825     0.300934  ...
# min       0.000000     0.000000  7.560700e+04     0.000000     0.000000  ...
# 25%       8.000000     8.000000  1.227980e+05     1.000000     0.000000  ...
# 50%      10.000000    12.000000  3.652000e+05     1.000000     0.000000  ...
# 75%      12.000000    12.000000  4.060240e+05     1.000000     0.000000  ...
# max      18.000000    18.000000  1.752340e+06     1.000000     1.000000  ...
#
#             smsa66         wage       enroll          KWW           IQ  \
# count  3010.000000  3010.000000  3010.000000  2963.000000  2061.000000
# mean      0.649502   577.282392     0.092359    33.540668   102.449782
# std       0.477205   262.958302     0.289580     8.611619    15.423756
# min       0.000000   100.000000     0.000000     4.000000    50.000000
# 25%       0.000000   394.250000     0.000000    28.000000    93.000000
# 50%       1.000000   537.500000     0.000000    34.000000   103.000000
# 75%       1.000000   708.750000     0.000000    40.000000   113.000000
# max       1.000000  2404.000000     1.000000    56.000000   149.000000
#
#            married     libcrd14        exper        lwage      expersq
# count  3003.000000  2997.000000  3010.000000  3010.000000  3010.000000
# mean      2.271395     0.674341     8.856146     6.261832    95.579070
# std       2.066823     0.468699     4.141672     0.443798    84.618314
# min       1.000000     0.000000     0.000000     4.605170     0.000000
# 25%       1.000000     0.000000     6.000000     5.976985    36.000000
# 50%       1.000000     1.000000     8.000000     6.286928    64.000000
# 75%       4.000000     1.000000    11.000000     6.563503   121.000000
# max       6.000000     1.000000    23.000000     7.784889   529.000000
#
# [8 rows x 34 columns]

# %%
df.head()
# Out:
#    id  nearc2  nearc4  educ  age  fatheduc  motheduc  weight  momdad14  \
# 0   2       0       0     7   29       NaN       NaN  158413         1
# 1   3       0       0    12   27       8.0       8.0  380166         1
# 2   4       0       0    12   34      14.0      12.0  367470         1
# 3   5       1       1    11   27      11.0      12.0  380166         1
# 4   6       1       1    12   34       8.0       7.0  367470         1
#
#    sinmom14  ...  smsa66  wage  enroll   KWW     IQ  married  libcrd14  exper  \
# 0         0  ...       1   548       0  15.0    NaN      1.0       0.0     16
# 1         0  ...       1   481       0  35.0   93.0      1.0       1.0      9
# 2         0  ...       1   721       0  42.0  103.0      1.0       1.0     16
# 3         0  ...       1   250       0  25.0   88.0      1.0       1.0     10
# 4         0  ...       1   729       0  34.0  108.0      1.0       0.0     16
#
#       lwage  expersq
# 0  6.306275      256
# 1  6.175867       81
# 2  6.580639      256
# 3  5.521461      100
# 4  6.591674      256
#
# [5 rows x 34 columns]

# %%
df.tail()
# Out:
#         id  nearc2  nearc4  educ  age  fatheduc  motheduc  weight  momdad14  \
# 3005  5218       0       1    12   25       8.0      12.0   82135         1
# 3006  5219       0       1    13   34       NaN       NaN   88765         1
# 3007  5220       0       1    12   24      11.0       NaN   89271         0
# 3008  5221       0       1    12   31       NaN       NaN  110376         1
# 3009  5225       0       1    13   26       NaN       NaN   81081         0
#
#       sinmom14  ...  smsa66  wage  enroll   KWW     IQ  married  libcrd14  \
# 3005         0  ...       0   335       0  15.0    NaN      1.0       0.0
# 3006         0  ...       0   481       0  43.0    NaN      1.0       1.0
# 3007         0  ...       0   500       0  25.0  109.0      1.0       0.0
# 3008         0  ...       0   713       0  32.0  107.0      1.0       1.0
# 3009         0  ...       0   525       1  27.0    NaN      1.0       0.0
#
#       exper     lwage  expersq
# 3005      7  5.814130       49
# 3006     15  6.175867      225
# 3007      6  6.214608       36
# 3008     13  6.569481      169
# 3009      7  6.263398       49
#
# [5 rows x 34 columns]

# %%
df.isna().sum()
# Out:
# id            0
# nearc2        0
# nearc4        0
# educ          0
# age           0
# fatheduc    690
# motheduc    353
# weight        0
# momdad14      0
# sinmom14      0
# step14        0
# reg661        0
# reg662        0
# reg663        0
# reg664        0
# reg665        0
# reg666        0
# reg667        0
# reg668        0
# reg669        0
# south66       0
# black         0
# smsa          0
# south         0
# smsa66        0
# wage          0
# enroll        0
# KWW          47
# IQ          949
# married       7
# libcrd14     13
# exper         0
# lwage         0
# expersq       0
# dtype: int64

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(df['wage'])
plt.title('Salary Hike')
plt.subplot(122)
plt.boxplot(df['exper'])
plt.title('Experience')
plt.show()

# %%
plt.boxplot(df['IQ'])
plt.title('IQ')
plt.show()

# %%
plt.boxplot(df['expersq'])
plt.title('Experience square')
plt.show()

# %%
plt.boxplot(df['educ'])
plt.title('Education')
plt.show()

# %%
indexDrop = df[(df['exper'] == 0)].index
df = df.drop(indexDrop)
indexDrop = df[(df['IQ'] == 0)].index
df = df.drop(indexDrop)
indexDrop = df[(df['black'] == 1)].index
df['black'].replace(to_replace= indexDrop, value = 2, inplace=True )
indexDrop = df[(df['black'] == 0)].index
df['black'].replace(to_replace= indexDrop, value = 1, inplace=True )
df = df.dropna(axis=0)

# %%
model = sm.ols('wage~educ+expersq+IQ+married', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     74.27
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           9.03e-58
# Time:                        00:46:23   Log-Likelihood:                -11040.
# No. Observations:                1596   AIC:                         2.209e+04
# Df Residuals:                    1591   BIC:                         2.212e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -203.6532     59.713     -3.411      0.001    -320.778     -86.529
# educ          41.7870      3.527     11.849      0.000      34.870      48.704
# expersq        1.2771      0.114     11.186      0.000       1.053       1.501
# IQ             1.7067      0.473      3.606      0.000       0.778       2.635
# married      -19.7044      3.099     -6.359      0.000     -25.782     -13.626
# ==============================================================================
# Omnibus:                      475.658   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1941.530
# Skew:                           1.385   Prob(JB):                         0.00
# Kurtosis:                       7.639   Cond. No.                     1.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model1 = sm.ols('np.sqrt(wage)~np.sqrt(educ)+np.sqrt(expersq)+np.sqrt(IQ)+np.sqrt(married)', data = df).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.sqrt(wage)   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     92.56
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           7.91e-71
# Time:                        00:46:23   Log-Likelihood:                -4691.0
# No. Observations:                1596   AIC:                             9392.
# Df Residuals:                    1591   BIC:                             9419.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          -11.6370      2.290     -5.082      0.000     -16.129      -7.145
# np.sqrt(educ)        6.5982      0.509     12.970      0.000       5.600       7.596
# np.sqrt(expersq)     0.5452      0.041     13.454      0.000       0.466       0.625
# np.sqrt(IQ)          0.8403      0.177      4.760      0.000       0.494       1.187
# np.sqrt(married)    -1.2102      0.198     -6.110      0.000      -1.599      -0.822
# ==============================================================================
# Omnibus:                       93.737   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.741
# Skew:                           0.470   Prob(JB):                     5.03e-33
# Kurtosis:                       4.162   Cond. No.                         278.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model2 = sm.ols('np.cbrt(wage)~np.cbrt(educ)+np.cbrt(expersq)+np.cbrt(IQ)+np.cbrt(married)', data = df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.cbrt(wage)   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     96.11
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           2.64e-73
# Time:                        00:46:23   Log-Likelihood:                -2328.5
# No. Observations:                1596   AIC:                             4667.
# Df Residuals:                    1591   BIC:                             4694.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -4.1788      0.783     -5.338      0.000      -5.714      -2.643
# np.cbrt(educ)        3.5443      0.271     13.088      0.000       3.013       4.075
# np.cbrt(expersq)     0.3819      0.028     13.853      0.000       0.328       0.436
# np.cbrt(IQ)          0.6569      0.129      5.080      0.000       0.403       0.911
# np.cbrt(married)    -0.4801      0.080     -6.027      0.000      -0.636      -0.324
# ==============================================================================
# Omnibus:                       32.664   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.729
# Skew:                           0.211   Prob(JB):                     4.32e-11
# Kurtosis:                       3.734   Cond. No.                         209.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model3 = sm.ols('np.log(wage)~np.log(educ)+np.log(expersq)+np.log(IQ)+np.log(married)', data = df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(wage)   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     92.82
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           5.19e-71
# Time:                        00:46:23   Log-Likelihood:                -708.70
# No. Observations:                1596   AIC:                             1427.
# Df Residuals:                    1591   BIC:                             1454.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.4349      0.339      4.232      0.000       0.770       2.100
# np.log(educ)        0.9638      0.078     12.347      0.000       0.811       1.117
# np.log(expersq)     0.1533      0.011     13.370      0.000       0.131       0.176
# np.log(IQ)          0.3890      0.072      5.432      0.000       0.249       0.530
# np.log(married)    -0.0805      0.013     -6.178      0.000      -0.106      -0.055
# ==============================================================================
# Omnibus:                       33.355   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.871
# Skew:                          -0.266   Prob(JB):                     8.09e-10
# Kurtosis:                       3.589   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.params
# Out:
# Intercept   -203.653238
# educ          41.786956
# expersq        1.277125
# IQ             1.706703
# married      -19.704399
# dtype: float64

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept    -3.410539
# educ         11.849046
# expersq      11.185590
# IQ            3.605727
# married      -6.358927
# dtype: float64
#  Intercept    6.645660e-04
# educ         4.236635e-31
# expersq      5.161094e-28
# IQ           3.208861e-04
# married      2.648332e-10
# dtype: float64

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.15734413439657458, 0.15522557785200275)

# %%
import statsmodels.api as sm
sm.qqplot(model3.resid, line = 'q')
plt.title('Normal Q-Q plot of residuals of Model without any data transformation')
plt.show()

# %% [markdown]
# Normal Q-Q residual plot to display a Q-Q plot assessing data skew and model fit. This chart displays the standardized residuals on the y-axis and the theoretical quantiles on the x-axis.

# %%
x = pd.read_csv('wage.csv')
indexDrop = x[(x['exper'] == 0)].index
x = x.drop(indexDrop)
indexDrop = x[(x['black'] == 1)].index
x['black'].replace(to_replace= indexDrop, value = 2, inplace=True )
indexDrop = x[(x['black'] == 0)].index
x['black'].replace(to_replace= indexDrop, value = 1, inplace=True )
x = x.dropna()

# %%
from sklearn.metrics import mean_squared_error

# %%
model1_pred_y =np.square(model1.predict(x[:100]))
model2_pred_y =pow(model2.predict(x[:100]),3)
model3_pred_y =np.exp(model3.predict(x[:100]))

# %%
model1_rmse =np.sqrt(mean_squared_error(x['wage'][:100], model1_pred_y))
model2_rmse =np.sqrt(mean_squared_error(x['wage'][:100], model2_pred_y))
model3_rmse =np.sqrt(mean_squared_error(x['wage'][:100], model3_pred_y))
print('model=', np.sqrt(model.mse_resid),'\n' 'model1=', model1_rmse,'\n' 'model2=', model2_rmse,'\n' 'model3=', model3_rmse)
# Out:
# model= 244.64267092879194
# model1= 219.88728508478218
# model2= 219.93305738793302
# model3= 224.06611490433704

# %%
rmse = {'model': np.sqrt(model.mse_resid), 'model1': model1_rmse, 'model2': model3_rmse, 'model3' : model3_rmse}
min(rmse, key=rmse.get)
# Out:
# 'model1'

# %%
predicted2 = pd.DataFrame()
predicted2['education'] = x['educ'][:100]
predicted2['expersq'] = x['expersq'][:100]
predicted2['married'] = x['married'][:100]
predicted2['IQ'] = x['IQ'][:100]
predicted2['Salary'] = x['wage'][:100]
predicted2['Predicted_wage'] = pd.DataFrame(np.square(model1.predict(x)))
predicted2
# Out:
#      education  expersq  married     IQ  Salary  Predicted_wage
# 1           12       81      1.0   93.0     481      529.920229
# 2           12      256      1.0  103.0     721      743.149619
# 3           11      100      1.0   88.0     250      500.472067
# 4           12      256      1.0  108.0     729      754.343817
# 5           12       64      1.0   85.0     500      489.225027
# ..         ...      ...      ...    ...     ...             ...
# 141         14       64      1.0  103.0     635      611.610451
# 143         13      225      1.0  109.0     615      778.063841
# 144         16       16      6.0  130.0     462      554.759716
# 145         12      256      1.0  105.0     865      747.649144
# 146         18       81      1.0  134.0     737      886.885494
#
# [100 rows x 6 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
# Out:
# Int64Index([65, 384, 747, 858, 1074, 1095, 1097, 1800, 2461], dtype='int64')

# %%
data = pd.read_csv('wage.csv', usecols = ['educ', 'expersq', 'IQ', 'married'])


indexDrop = data[(data['expersq'] == 0)].index
data = data.drop(indexDrop)
data = data.dropna()
X = np.array(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 1 to 3008
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   educ     2055 non-null   int64
#  1   IQ       2055 non-null   float64
#  2   married  2055 non-null   float64
#  3   expersq  2055 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 80.3 KB

# %%
data = pd.read_csv('wage.csv', usecols = ['wage','educ', 'expersq', 'IQ', 'married'])



indexDrop = data[(data['expersq'] == 0)].index
data = data.drop(indexDrop)
data = data.dropna()
y = np.array(data['wage']).reshape(-1,1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3001 entries, 0 to 3009
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   wage     3001 non-null   int64
#  1   expersq  3001 non-null   int64
# dtypes: int64(2)
# memory usage: 70.3 KB

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2417, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2414 if n_arrays == 0:
#    2415     raise ValueError("At least one array required as input")
# -> 2417 arrays = indexable(*arrays)
#    2419 n_samples = _num_samples(arrays[0])
#    2420 n_train, n_test = _validate_shuffle_split(
#    2421     n_samples, test_size, train_size, default_test_size=0.25
#    2422 )
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:378, in indexable(*iterables)
#     359 """Make arrays indexable for cross-validation.
#     360
#     361 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     374     sparse matrix, or dataframe) or `None`.
#     375 """
#     377 result = [_make_indexable(X) for X in iterables]
# --> 378 check_consistent_length(*result)
#     379 return result
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [2055, 3001]

# %%
predicted2.to_excel('output.xlsx')
